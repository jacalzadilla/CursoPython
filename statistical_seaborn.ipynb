# %% [markdown]
# ## Statistical Seaborn

# %%
import pandas as pd
import os 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path=os.getcwd()
data_path = os.path.join(path, 'data')
df=pd.read_csv(os.path.join(data_path, 'Terminos_lagoon_TA_DIC_2023_RawData.csv'))

# %%
my_colors = ["#5ec962", "#3b528b"]

# add color array to set_palette
sns.set(font_scale=2, style="ticks", palette= my_colors)

# %%
ax = sns.catplot(data=df,
                 x="area", y="ta_micromol_kg",
                hue="season", col="estuary",
                kind="box", 
                height=7, aspect=1)

  
ax.set(xlabel='', ylabel=' TA ($\mu mol \; kg^{-1}$)')

ax.set_titles(col_template="{col_name}", row_template="{row_name}")

plt.setp(ax._legend.get_title(), fontsize=20)

sns.despine(top=False,right=False)

plt.show()

# %%
ax = sns.catplot(data=df, 
                x="area", y="ta_micromol_kg",
                hue="season", col="estuary", 
                kind="violin", 
                height=7, aspect=1)

  
ax.set(xlabel='', ylabel=' TA ($\mu mol \; kg^{-1}$)')

ax.set_titles(col_template="{col_name}", row_template="{row_name}")

plt.setp(ax._legend.get_title(), fontsize=20)

sns.despine(top=False,right=False)

plt.show()

# %%
# Draw a pointplot to show pulse as a function of three categorical factors
ax = sns.catplot(
    data=df, x="season", 
    y="ta_micromol_kg", hue="estuary", col="area",
    capsize=.2, palette="YlGnBu_d", errorbar="se",
    kind="point", height=6, aspect=.75,
)
ax.despine(left=True)

ax.set(xlabel='', ylabel=' TA ($\mu mol \; kg^{-1}$)')

ax.set_titles(col_template="{col_name}", row_template="{row_name}")

plt.setp(ax._legend.get_title(), fontsize=20)

sns.despine(top=False,right=False)

plt.show()

# %%
ax = sns.lmplot(x="sal_psu", y="ta_micromol_kg",
                hue="season",col="estuary",
                data=df, 
                height=7, aspect=1)

ax.set(xlabel='Salinity (PSU)', ylabel=' DIC ($\mu mol \; kg^{-1}$)')

ax.set_titles(col_template="{col_name}", row_template="{row_name}")

plt.setp(ax._legend.get_title(), fontsize=20)

sns.despine(top=False,right=False)

plt.show()

# %% [markdown]
# ## Respuesta de la tarea

# %%
df_wave=pd.read_csv(os.path.join('data','ERA5_anual.csv'))

# %%
g=sns.jointplot(data=df_wave, x="swh", y="mwp", cmap=plt.cm.jet, kind="hist", bins=200)
g.ax_joint.set_xlabel('Significant Wave Height (m)')
g.ax_joint.set_ylabel('Mean Wave Period (s)')
g.plot_marginals(sns.histplot, color="blue", alpha=1, bins=50)
g.fig.set_size_inches(5, 5)
